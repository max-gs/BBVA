# %% [markdown]
# ## PYTHON EXAM

# %% [markdown]
# El banco BBVA desea hacer un estudio de sus clientes, para esto se requiere analizar el comportamiento de distintos usuarios de tarjeta de crédito con el fin de incentivar el uso del producto. Se proporcionan 3 insumos definidos de la siguiente forma:
#
# *   CardBase
# *   CustomerBase
# *   TransactionBase

# %% [markdown]
# Inicialmente se requiere cargar la información a partir de los archivos suministrados, cabe destacar que para realizar los distintos movimientos (query) se debe organizar los datos de tal forma que se tengan tipos de datos congruentes (palabras=string, números=integer), esto debido a que todo se lee inicialmente (por defecto) de tipo string.

# %% [markdown]
# ##TEST

# %% [markdown]
# 1) Levantar los 3 archivos

# %%
#Desarrollar

# %% [markdown]
# 2) Mostrar el contenido de cada archivo

# %%
#Desarrollar

# %% [markdown]
# 3) Realizar una consulta que muestre las Card_Family=Premium y cuyo limite de credito(Credit_Limit) sea de 490000 a 564000, mostrar este resultado de manera ascendente.

# %% [markdown]
# Resultado ejemplo:
#
# ![image.png](data:image/png;base64,...)

# %%
#Desarrollar

# %% [markdown]
# 4) Realizar una consulta que muestre los campos Card_Number, Card_Family y Cust_ID cuyo valores comiencen con "CC5"

# %% [markdown]
# Resultado ejemplo:
#
# ![image.png](data:image/png;base64,...)

# %%
#Desarrollar

# %% [markdown]
# 3) Realizar una consulta que muestre la última fecha de transacción (Transaction_Date) que se hizo
# para cada Credit_Card_ID
#
# Nota: La columna con la última fecha de transacción debe quedar con su mismo nombre de columna

# %% [markdown]
# Resultado ejemplo:
#
# ![image.png](data:image/png;base64,...)

# %%
#Desarrollar

# %% [markdown]
# 6) Unir las tablas CardBase y CustomerBase, realizar una consulta que muestre "Cust_ID","Card_Number","Card_Family","Customer_Vintage_Group" done Card_family=Gold y Customer_Vintage_Group=VG2

# %% [markdown]
# Resultado ejemplo:
#
# ![image.png](data:image/png;base64,...)

# %%
#Desarrollar
